# %% [markdown]
# # Olist EDA con DuckClaw
#
# Análisis de comportamiento de clientes y tendencias de ventas usando **DuckClaw**, DuckDB + consultas en lenguaje natural y **gráficas** con matplotlib/seaborn.
#
# **LLM:** Groq (`provider="groq"`), **DeepSeek** (`provider="deepseek"`), o **MLX local** (`provider="mlx"`). Groq y DeepSeek requieren su `API_KEY` (`GROQ_API_KEY`, `DEEPSEEK_API_KEY`). Para MLX, arranca antes el motor con PM2: `pm2 start ecosystem.config.cjs` (puerto 8080). Ver README y `docs/pm2-migration.md`.

# %% [markdown]
# ## Resumen: Instalación, configuración y uso de DuckClaw
#
# ### a. Instalación
#
# **Prerrequisitos:** macOS (Apple Silicon), CMake ≥ 3.18, DuckDB, Pybind11.
#
# ```bash
# # Desde la raíz del repo
# git clone https://github.com/Arevalojj2020/duckclaw.git
# cd duckclaw
#
# # Con pip
# pip install cmake pybind11
# pip install -e . --no-build-isolation
#
# # Con uv (recomendado)
# uv pip install -e .
#
# # Para LLM Groq
# pip install -e ".[groq]"
# ```
#
# La primera compilación tarda ~5–7 min (descarga y compila DuckDB).
#
# ### b. Configuración
#
# - **Datos Olist:** Coloca los CSV en `data/` (olist_orders_dataset.csv, olist_customers_dataset.csv, etc.).
# - **LLM (lenguaje natural):** Elige un proveedor y configura su API key en `.env` o variables de entorno:
#   - **Groq:** `GROQ_API_KEY` → `export GROQ_API_KEY='tu-api-key'`
#   - **DeepSeek:** `DEEPSEEK_API_KEY` → `export DEEPSEEK_API_KEY='tu-api-key'`
#   - **MLX (local):** Arranca el motor con `pm2 start ecosystem.config.cjs` (puerto 8080).
#
# ### c. Uso básico
#
# ```python
# import duckclaw
# from duckclaw.bi import load_olist_data, ask_bi, get_top_sellers
#
# db = duckclaw.DuckClaw(str(DB_PATH))
# load_olist_data(db, "data")
#
# # Consultas directas
# get_top_sellers(db, limit=10)
#
# # Preguntas en lenguaje natural (requiere LLM configurado)
# respuesta = ask_bi(db, "¿Mejores vendedores?", provider="groq")
# ```
#
# ---

# %% [markdown]
# ## 1. Configuración y carga de datos
#
# Creamos la base DuckClaw y cargamos los CSV de Olist desde `data/` **con esquema explícito** (tipos definidos: VARCHAR, INTEGER, DECIMAL, etc.).
#
# **Requisitos para lenguaje natural:** Groq (`GROQ_API_KEY`), DeepSeek (`DEEPSEEK_API_KEY`) o MLX local (antes: `pm2 start ecosystem.config.cjs`).

# %%
import json
import duckclaw
from pathlib import Path

# Ruta al repo: desde repo root (data/) o desde notebooks/ (../data/)
REPO_ROOT = Path.cwd() if (Path.cwd() / "data" / "olist_orders_dataset.csv").exists() else Path.cwd().parent
DATA_DIR = REPO_ROOT / "data"
DB_PATH = str(REPO_ROOT / "olist_bi.duckdb")

db = duckclaw.DuckClaw(str(DB_PATH))

# %%
print(db)
# Out:
# <duckclaw._duckclaw.DuckClaw object at 0x1111129b0>

# %%
from duckclaw.bi import load_olist_data

# Carga con esquema explícito (tipos correctos por columna). Si falla, reinicia el kernel para recargar el módulo.
counts = load_olist_data(db, str(DATA_DIR))
print("Tablas cargadas:")
for table, n in counts.items():
    print(f"  {table}: {n:,} filas")
# Out:
# Tablas cargadas:
#   olist_orders: 99,441 filas
#   olist_customers: 99,441 filas
#   olist_order_items: 112,650 filas
#   olist_order_payments: 103,886 filas
#   olist_order_reviews: 99,224 filas
#   olist_products: 32,951 filas
#   olist_sellers: 3,095 filas
#   product_category_name_translation: 71 filas
#   olist_geolocation: 1,000,163 filas

# %%
import importlib
import duckclaw.bi.olist
import duckclaw.bi.agent
importlib.reload(duckclaw.bi.olist)
importlib.reload(duckclaw.bi.agent)
# Out:
# <module 'duckclaw.bi.agent' from '/Users/juanjosearevalocamargo/Desktop/duckclaw/duckclaw/bi/agent.py'>

# %% [markdown]
# ### Protocolo de respuesta estructurada MLX (Olist)
#
# Con `provider="mlx"`, el agente usa el formato `<thought>`, `<tool_call>`, `<answer>`. Si el modelo devuelve tool-calls crudos en texto (ej. `{"name": "get_top_sellers", "parameters": {...}}`), el **normalizador** los detecta, ejecuta las herramientas DuckClaw y compone la respuesta final. No se muestran tool-calls crudos ni sufijos como `<|eom_id|>`.

# %% [markdown]
# ## 2. Preguntas de negocio obligatorias
#
# ### 2.1 Clientes que más generan ventas

# %%
# MLX: formato estructurado; si el modelo devuelve tool-calls crudos, el normalizador los ejecuta.
from pathlib import Path
from duckclaw.bi import load_olist_data, ask_bi

respuesta = ask_bi(
    db,
    "¿Quiénes son los mejores vendedores y cuál es el tiempo medio de entrega?",
    provider="deepseek",
)
print(respuesta)
# Out:
# <thought>
# 1. Análisis de resultados: Tenemos los datos de los mejores vendedores y las métricas de entrega.
# 2. Identificación de la necesidad: Presentar la información de manera clara y comprensible.
# 3. Decisión: Proporcionar un resumen con los datos obtenidos.
# </thought>
# <answer>
# ## Mejores Vendedores (Top 10 por ventas totales):
#
# 1. **Vendedor ID: 4869f7a5dfa277a7dca6462dcf3b52b2** - Guariba/SP
#    - Ventas totales: R$ 247.007,06
#    - Número de pedidos: 1.124
#
# 2. **Vendedor ID: 7c67e1448b00f6e969d365cea6b010ab** - Itaquaquecetuba/SP
#    - Ventas totales: R$ 237.806,69
#    - Número de pedidos: 973
#
# 3. **Vendedor ID: 4a3ca9315b744ce9f8e9374361493884** - Ibitinga/SP
#    - Ventas totales: R$ 231.220,43
#    - Número de pedidos: 1.772
#
# 4. **Vendedor ID: 53243585a1d6dc2643021fd1853d8905** - Lauro de Freitas/BA
#    - Ventas totales: R$ 230.797,02
#    - Número de pedidos: 348
#
# 5. **Vendedor ID: fa1c13f2614d7b5c4749cbc52fecda94** - Sumaré/SP
#    - Ventas totales: R$ 200.833,50
#    - Número de pedidos: 578
#
# 6. **Vendedor ID: da8622b14eb17ae2831f4ac5b9dab84a** - Piracicaba/SP
#    - Ventas totales: R$ 184.706,78
#    - Número de pedidos: 1.311
#
# 7. **Vendedor ID: 7e93a43ef30c4f03f38b393420bc753a** - Barueri/SP
#    - Ventas totales: R$ 171.973,55
#    - Número de pedidos: 319
#
# 8. **Vendedor ID: 1025f0e2d44d7041d6cf58b6550e0bfa** - São Paulo/SP
#    - Ventas totales: R$ 171.924,96
#    - Número de pedidos: 910
#
# 9. **Vendedor ID: 7a67c85e85bb2ce8582c35f2203ad736** - São Paulo/SP
#    - Ventas totales: R$ 160.278,52
#    - Número de pedidos: 1.145
#
# 10. **Vendedor ID: 955fee9216a65b617aa5c0531780ce60** - São Paulo/SP
#     - Ventas totales: R$ 156.606,48
#     - Número de pedidos: 1.261
#
# ## Tiempo Medio de Entrega:
#
# - **Pedidos entregados analizados:** 96.470
# - **Tiempo promedio de entrega:** 12,5 días
# - **Entrega más rápida:** 0 días (mismo día)
# - **Entrega más lenta:** 210 días
#
# **Observación:** El vendedor de Guariba/SP lidera el ranking con R$ 247.007,06 en ventas totales, mientras que el tiempo promedio de entrega en toda la plataforma es de 12,5 días. La mayoría de los mejores vendedores se concentran en el estado de São Paulo.
# </answer>

# %% [markdown]
# ### 2.2 ¿A qué clientes debo fidelizar?

# %%
respuesta = ask_bi(
    db,
    "¿A que clientes deberia fidelizar?",
    provider="deepseek",
)
print(respuesta)
# Out:
# <answer>
# Basándome en el análisis de los datos, puedo identificar los clientes que deberías priorizar para fidelización. Aunque la herramienta específica de fidelización no encontró clientes con múltiples pedidos, los datos muestran claramente quiénes son tus clientes más valiosos:
#
# **Top 5 clientes para fidelizar:**
#
# 1. **Cliente de Rio de Janeiro (RJ)**: Generó R$ 13.664,08 en una sola compra
# 2. **Cliente de Vila Velha (ES)**: R$ 7.274,88 en una compra
# 3. **Cliente de Campo Grande (MS)**: R$ 6.929,31 en una compra
# 4. **Cliente de Vitória (ES)**: R$ 6.922,21 en una compra
# 5. **Cliente de Marília (SP)**: R$ 6.726,66 en una compra
#
# **Observación importante**: Todos estos clientes han realizado solo 1 pedido, lo que indica una gran oportunidad de fidelización. Son clientes de alto valor que hicieron compras significativas pero aún no han vuelto a comprar.
#
# **Recomendaciones de fidelización**:
# - Implementar programas de recompensas para clientes de alto valor
# - Contactar a estos clientes con ofertas personalizadas
# - Crear un programa de fidelidad que incentive compras recurrentes
# - Segmentar por ubicación geográfica (RJ, ES, SP, MS son los estados con clientes más valiosos)
#
# Estos clientes representan un gran potencial de ingresos recurrentes si logras convertirlos en clientes fieles.
# </answer>

# %% [markdown]
# ### 2.3 ¿Cuáles son mis mejores vendedores?

# %%
respuesta = ask_bi(
    db,
    "¿Cuales son mis mejores vendedores?",
    provider="deepseek",
)
print(respuesta)
# Out:
# Los mejores vendedores son: guariba (247,007.1), itaquaquecetuba (237,806.7), ibitinga (231,220.4), lauro de freitas (230,797.0), sumare (200,833.5). Total: 15 vendedores.

# %% [markdown]
# ### 2.4 ¿Cuál es el promedio de tiempos de entrega? ¿Hay casos críticos?

# %%
respuesta = ask_bi(
    db,
    "¿Cual es el promedio de tiempo de entrega, hay casos críticos?",
    provider="deepseek",
)
print(respuesta)
# Out:
# <thought>
# He obtenido los datos solicitados. Ahora debo presentar la información de manera clara y completa al usuario.
# </thought>
# <answer>
# **Promedio de tiempo de entrega:**
# - **Promedio:** 12.50 días
# - **Mínimo:** 0 días (entregas el mismo día)
# - **Máximo:** 210 días (aproximadamente 7 meses)
# - **Total de pedidos entregados:** 96,470
#
# **Casos críticos de entrega (más de 20 días):**
# Sí, existen casos críticos de entregas muy tardías. He identificado 30 pedidos con tiempos de entrega extremadamente largos, siendo los más graves:
#
# 1. **210 días** - Pedido del 21/02/2017 entregado el 19/09/2017
# 2. **208 días** - Pedido del 23/02/2018 entregado el 19/09/2018
# 3. **196 días** - Pedido del 07/03/2017 entregado el 19/09/2017
#
# **Observaciones importantes:**
# - El tiempo de entrega promedio es de 12.5 días, lo que parece razonable para comercio electrónico.
# - Sin embargo, existen casos extremos donde las entregas superan los 6 meses, lo que representa un problema grave de logística.
# - Muchos de los casos más críticos (con entregas alrededor de 190-210 días) tienen fechas de entrega concentradas en septiembre de 2017 y 2018, lo que podría indicar problemas sistémicos en esos períodos.
# - El caso más extremo de 210 días es particularmente preocupante y merece investigación específica.
#
# **Recomendación:** Se sugiere investigar los pedidos con más de 100 días de entrega para identificar patrones comunes (región, vendedor, transportista) y tomar medidas correctivas.
# </answer>

# %% [markdown]
# ## 3. Preguntas adicionales de negocio
#
# ### Resumen de ventas (ticket, total)

# %%
respuesta = ask_bi(
    db,
    "Haz un resumen ejecutivo de ventas y ticket promedio",
    provider="deepseek",
)
print(respuesta)
# Out:
# <thought>
# He obtenido los datos del resumen ejecutivo de ventas. Ahora proporcionaré la respuesta final al usuario con estos datos en lenguaje natural.
# </thought>
# <answer>
# **Resumen Ejecutivo de Ventas - Olist**
#
# Aquí tienes los principales KPIs de ventas de la tienda online:
#
# 📊 **Total de Pedidos:** 96,478 pedidos realizados
#
# 💰 **Ventas Totales:** R$ 15,419,773.75 (aproximadamente 15.4 millones de reales)
#
# 🎫 **Ticket Promedio:** R$ 159.83 por pedido
#
# Este resumen muestra que la tienda ha procesado casi 100,000 pedidos con un valor promedio de compra de aproximadamente R$ 160. Estos datos proporcionan una visión general del volumen de negocio y el comportamiento de compra promedio de los clientes.
# </answer>

# %% [markdown]
# ### Satisfacción (reviews)

# %%
respuesta = ask_bi(
    db,
    "Haz un resumen ejecutivo de reviews",
    provider="deepseek",
)
print(respuesta)
# Out:
# <thought>
# He obtenido los datos de métricas de reviews. Ahora debo presentarlos en un formato de resumen ejecutivo claro y comprensible para el usuario.
# </thought>
# <answer>
# ## Resumen Ejecutivo de Reviews - Olist
#
# ### 📊 Métricas Principales
#
# **Puntuación Media:** 4.09/5 ⭐
# - Esta puntuación indica un nivel de satisfacción general bueno por parte de los clientes.
#
# **Total de Reviews:** 99,224
# - Base de datos sólida de feedback de clientes para análisis.
#
# **Distribución de Valoraciones:**
# - **Reviews Positivas (≥4 estrellas):** 76,470 (77.1% del total)
# - **Reviews Negativas (≤3 estrellas):** 14,575 (14.7% del total)
#
# ### 📈 Análisis de Satisfacción
#
# 1. **Satisfacción Alta:** Con una puntuación media de 4.09, los clientes muestran un nivel de satisfacción general positivo.
# 2. **Tasa de Satisfacción:** El 77.1% de los clientes otorga valoraciones de 4 o 5 estrellas, lo que indica una experiencia de compra satisfactoria para la mayoría.
# 3. **Área de Mejora:** Aproximadamente el 14.7% de las reviews son negativas (3 estrellas o menos), lo que representa oportunidades para mejorar la experiencia del cliente.
#
# ### 🎯 Recomendaciones
#
# 1. **Análisis de Reviews Negativas:** Investigar las causas principales de las 14,575 reviews negativas para identificar áreas críticas de mejora.
# 2. **Segmentación por Categoría:** Sería útil analizar la satisfacción por categoría de producto para identificar productos problemáticos.
# 3. **Seguimiento de Tendencias:** Monitorear la evolución de la puntuación media a lo largo del tiempo para medir el impacto de mejoras implementadas.
#
# Este resumen proporciona una visión general del nivel de satisfacción de los clientes en la plataforma Olist.
# </answer>

# %% [markdown]
# ### Ventas por categoría de producto

# %%
respuesta = ask_bi(
    db,
    "Haz un resumen ejecutivo de ventas por categoria",
    provider="deepseek",
)
print(respuesta)
# Out:
# <thought>
# He obtenido los datos de ventas por categoría. Ahora puedo proporcionar un resumen ejecutivo con los insights más relevantes.
# </thought>
# <answer>
# ## Resumen Ejecutivo de Ventas por Categoría
#
# ### Top 5 Categorías por Ventas Totales:
#
# 1. **Salud y Belleza (health_beauty)**: R$ 1.412.089,53
#    - 8.647 pedidos
#    - Categoría líder en ventas totales
#
# 2. **Relojes y Regalos (watches_gifts)**: R$ 1.264.333,12
#    - 5.495 pedidos
#    - Alto valor promedio por pedido
#
# 3. **Cama, Baño y Mesa (bed_bath_table)**: R$ 1.225.209,26
#    - 9.272 pedidos (mayor volumen de pedidos)
#    - Categoría con más transacciones
#
# 4. **Deportes y Ocio (sports_leisure)**: R$ 1.118.256,91
#    - 7.530 pedidos
#
# 5. **Computadoras y Accesorios (computers_accessories)**: R$ 1.032.723,77
#    - 6.530 pedidos
#
# ### Insights Clave:
#
# **Volumen vs. Valor:**
# - **Cama, Baño y Mesa** tiene el mayor número de pedidos (9.272) pero ocupa el tercer lugar en ventas totales.
# - **Relojes y Regalos** tiene menos pedidos (5.495) pero genera el segundo mayor volumen de ventas, indicando productos de mayor valor unitario.
#
# **Categorías de Alto Valor:**
# - **Salud y Belleza** lidera tanto en ventas totales como en volumen de pedidos, mostrando una categoría sólida y popular.
# - **Relojes y Regalos** tiene el segundo mejor desempeño con un ticket promedio alto.
#
# **Categorías Emergentes:**
# - **Muebles y Decoración** (6º lugar) y **Artículos para el Hogar** (7º lugar) muestran buen desempeño en el segmento del hogar.
#
# **Distribución de Ventas:**
# Las 5 categorías principales representan aproximadamente el 60% del total de ventas analizadas, mostrando una concentración moderada en categorías clave.
#
# **Recomendaciones:**
# 1. Fortalecer el inventario en Salud y Belleza, manteniendo su posición de liderazgo.
# 2. Explorar oportunidades de crecimiento en Relojes y Regalos, donde el valor por pedido es alto.
# 3. Optimizar operaciones en Cama, Baño y Mesa para mejorar márgenes dado su alto volumen.
# </answer>

# %% [markdown]
# ## 4. Uso opcional con pandas
#
# Si tienes `pandas`, puedes convertir los resultados a DataFrame para tablas y gráficos.

# %%
try:
    import pandas as pd
    from duckclaw.bi import get_top_customers_by_sales
    df_top = pd.DataFrame(get_top_customers_by_sales(db, limit=10))
    display(df_top)
except Exception as e:
    print("Sin pandas o display:", e)
# Out:
#                         customer_id   customer_city customer_state  \
# 0  1617b1357756262bfa56ab541c47bc16  rio de janeiro             RJ
# 1  ec5b2ba62e574342386871631fafd3fc      vila velha             ES
# 2  c6e2731c5b391845f6800c97401a43a9    campo grande             MS
# 3  f48d464a0baaea338cb25f816991ab1f         vitoria             ES
# 4  3fd6777bbce08a352fddd04e4a7cc8f6         marilia             SP
# 5  05455dfa7cd02f13d132aa7a6a9729c6     divinopolis             MG
# 6  df55c14d1476a9a3467f131269c2477f        araruama             RJ
# 7  24bbf5fd2f2e1b359ee7de94defc4a15            maua             SP
# 8  3d979689f636322c62418b6346b1c6d2     joao pessoa             PB
# 9  1afc82cd60e303ef09b4ef9837c9505c       sao paulo             SP
#
#   total_sales num_orders
# 0    13664.08          1
# 1     7274.88          1
# 2     6929.31          1
# 3     6922.21          1
# 4     6726.66          1
# 5     6081.54          1
# 6     4950.34          1
# 7     4764.34          1
# 8     4681.78          1
# 9     4513.32          1

# %% [markdown]
# ## 5. Gráficas con DuckClaw (matplotlib y seaborn)
#
# Puedes **generar gráficas** con lenguaje natural:
#
# 1. En el chatbot: pide *"muéstrame un gráfico de ventas por categoría"* o *"gráfica de los mejores vendedores"* y el agente guardará la imagen en la carpeta `output/`.

# %%
import re
from pathlib import Path
from IPython.display import Image, display

OUT = Path("output")
OUT.mkdir(exist_ok=True)

respuesta_grafica = ask_bi(db, "Muéstrame un gráfico de ventas por categoría de producto.", provider="deepseek")
print(respuesta_grafica)

# Extraer y mostrar la imagen si la respuesta contiene una ruta .png
img_match = re.search(r'([\w\-./:]+\.(?:png|jpg|jpeg|webp))', respuesta_grafica, re.IGNORECASE)
if img_match:
    img_path = Path(img_match.group(1))
    if not img_path.exists() and not img_path.is_absolute():
        img_path = OUT / img_path.name
    if img_path.exists():
        display(Image(filename=str(img_path)))
# Out:
# <answer>
# He generado un gráfico de barras con las ventas por categoría de producto. El gráfico muestra las 12 categorías principales ordenadas por volumen de ventas. Puedes encontrar la imagen guardada en: /Users/juanjosearevalocamargo/Desktop/duckclaw/notebooks/output/ventas_por_categoria.png
#
# El gráfico te permitirá identificar rápidamente qué categorías de productos son las más vendidas en la tienda online Olist, lo que puede ser útil para tomar decisiones sobre inventario, marketing y estrategias comerciales.</answer>

# %% [markdown]
# ### Nota
# Cuando pidas gráficas por lenguaje natural, el agente devuelve la ruta del archivo generado (por ejemplo en `output/`). Si quieres visualizarlo en notebook, usa `IPython.display.Image`.

# %% [markdown]
# ## 6. Chatbot con log + render automático de gráficas (VFS)
#
# Esta sección agrega una experiencia tipo chat con trazabilidad persistente en **VFS local**:
# - Guarda cada interacción en `vfs/bi_chat_memory.duckdb` (tabla `bi_chat_log`)
# - Campos: `timestamp`, `input`, `output`, `image_path`, `provider`
# - Si el agente devuelve una ruta de imagen (`.png/.jpg/.jpeg/.webp`), la muestra automáticamente en el notebook.

# %%
import json
import re
from datetime import datetime
from pathlib import Path

import duckclaw
from IPython.display import Image, display
from duckclaw.bi import ask_bi

# Persistencia en VFS local
VFS_DIR = REPO_ROOT / 'vfs'
VFS_DIR.mkdir(parents=True, exist_ok=True)
CHAT_DB_PATH = VFS_DIR / 'bi_chat_memory.duckdb'
chat_db = duckclaw.DuckClaw(str(CHAT_DB_PATH))

chat_db.execute("""
CREATE TABLE IF NOT EXISTS bi_chat_log (
    created_at TEXT,
    input_text TEXT,
    output_text TEXT,
    image_path TEXT,
    provider TEXT
)
""")

MAX_CHAT_ROWS = 1000
AUTO_PRUNE = True

print(f'🗄️ VFS chat memory: {CHAT_DB_PATH}')
print(f'🧹 Rotación automática: {AUTO_PRUNE} (máx {MAX_CHAT_ROWS} filas)')

CHAT_LOG = []

def _esc(s: str) -> str:
    return str(s).replace("'", "''")

def _extract_image_path(text: str):
    if not text:
        return None
    pattern = r'([\w\-./]+\.(?:png|jpg|jpeg|webp))'
    m = re.search(pattern, text, flags=re.IGNORECASE)
    if not m:
        return None
    raw = m.group(1)
    p = Path(raw)
    candidates = [p, Path.cwd() / p, Path.cwd().parent / p]
    for c in candidates:
        if c.exists():
            return c.resolve()
    return None

def _query_json(sql: str):
    raw = chat_db.query(sql)
    return json.loads(raw) if isinstance(raw, str) else (raw or [])

def chat_log_count() -> int:
    rows = _query_json('SELECT COUNT(*) AS n FROM bi_chat_log')
    return int(rows[0]['n']) if rows else 0

def prune_chat_log(keep_last: int = MAX_CHAT_ROWS):
    keep_last = int(keep_last)
    if keep_last <= 0:
        return 0
    total = chat_log_count()
    if total <= keep_last:
        return 0
    rows = _query_json(
        f"SELECT created_at FROM bi_chat_log ORDER BY created_at DESC LIMIT 1 OFFSET {keep_last - 1}"
    )
    if not rows:
        return 0
    cutoff = rows[0]['created_at']
    before = total
    chat_db.execute(
        f"DELETE FROM bi_chat_log WHERE created_at < '{_esc(cutoff)}'"
    )
    after = chat_log_count()
    return max(before - after, 0)

def chat_log_stats():
    total = chat_log_count()
    provider_rows = _query_json(
        'SELECT provider, COUNT(*) AS n FROM bi_chat_log GROUP BY provider ORDER BY n DESC'
    )
    latest_rows = _query_json(
        'SELECT created_at FROM bi_chat_log ORDER BY created_at DESC LIMIT 1'
    )
    latest = latest_rows[0]['created_at'] if latest_rows else ''
    return {
        'total_rows': total,
        'providers': provider_rows,
        'latest_timestamp': latest,
    }

def _save_chat_record(question: str, answer: str, image_path: str, provider: str):
    ts = datetime.now().isoformat(timespec='seconds')
    chat_db.execute(
        'INSERT INTO bi_chat_log (created_at, input_text, output_text, image_path, provider) ' +
        f"VALUES ('{_esc(ts)}', '{_esc(question)}', '{_esc(answer)}', '{_esc(image_path)}', '{_esc(provider)}')"
    )
    if AUTO_PRUNE:
        prune_chat_log(MAX_CHAT_ROWS)

def load_chat_log(limit: int = 200):
    return _query_json(
        'SELECT created_at AS timestamp, input_text AS input, output_text AS output, image_path, provider ' +
        f"FROM bi_chat_log ORDER BY created_at DESC LIMIT {int(limit)}"
    )

def ask_bi_with_log(question: str, provider: str = 'groq', save_traces: bool = False, send_to_langsmith: bool = False):
    answer = ask_bi(db, question, provider=provider, save_traces=save_traces, send_to_langsmith=send_to_langsmith)
    image = _extract_image_path(answer)
    image_str = str(image) if image else ''

    record = {
        'timestamp': datetime.now().isoformat(timespec='seconds'),
        'input': question,
        'output': answer,
        'image_path': image_str,
        'provider': provider,
    }
    CHAT_LOG.append(record)
    _save_chat_record(question, answer, image_str, provider)
    return answer, image
# Out:
# 🗄️ VFS chat memory: /Users/juanjosearevalocamargo/Desktop/duckclaw/vfs/bi_chat_memory.duckdb
# 🧹 Rotación automática: True (máx 1000 filas)

# %%
# Chat interactivo con render automático de gráfica (Groq, DeepSeek o MLX)
PROVIDER = 'deepseek'  # 'groq', 'deepseek' o 'mlx' (MLX requiere: pm2 start ecosystem.config.cjs)
print(f"🤖 BI Chat Pro ({PROVIDER}) listo. Escribe tu pregunta (o 'salir').")
while True:
    q = input("👤 Tú: ").strip()
    if not q:
        continue
    if q.lower() in ('salir', 'exit', 'quit', 'q'):
        print("👋 Fin de la sesión.")
        break
    print("👤 Tú:", q)

    ans, img = ask_bi_with_log(q, provider=PROVIDER, save_traces=True, send_to_langsmith=True)
    print("📊 BI:", ans)

    if img is not None:
        print(f"🖼️ Mostrando gráfica: {img}")
        display(Image(filename=str(img)))

    print('-' * 90)
# Out:
# 🤖 BI Chat Pro (deepseek) listo. Escribe tu pregunta (o 'salir').
# 👤 Tú: que tablas hay disponibles?
# 📊 BI: Tablas disponibles: olist_customers, olist_geolocation, olist_order_items, olist_order_payments, olist_order_reviews, olist_orders, olist_products, olist_sellers, product_category_name_translation.
# ------------------------------------------------------------------------------------------
# 👤 Tú: haz un diagrama de torta con el top 5 de categorias por ventas
# 📊 BI: <answer>
# He generado el diagrama de torta con las 5 categorías principales por ventas. El gráfico se ha guardado en la ruta: /Users/juanjosearevalocamargo/Desktop/duckclaw/notebooks/output/ventas_por_categoria_torta.png
#
# El diagrama muestra la distribución porcentual de ventas entre las categorías más importantes, permitiendo visualizar rápidamente cuáles son las categorías que más contribuyen al total de ventas de la tienda online.
# </answer>
# 🖼️ Mostrando gráfica: /Users/juanjosearevalocamargo/Desktop/duckclaw/notebooks/output/ventas_por_categoria_torta.png
# ------------------------------------------------------------------------------------------
# 👤 Tú: haz un diagrama de barras con las ventas por mes de 2017
# 📊 BI: <answer>
# He generado el diagrama de barras con las ventas por mes de 2017. El gráfico se ha guardado en la ruta: /Users/juanjosearevalocamargo/Desktop/duckclaw/notebooks/output/ventas_por_mes.png
#
# Este gráfico muestra la evolución de las ventas mensuales durante todo el año 2017, permitiendo visualizar los meses con mayor y menor actividad comercial.
# </answer>
# 🖼️ Mostrando gráfica: /Users/juanjosearevalocamargo/Desktop/duckclaw/notebooks/output/ventas_por_mes.png
# ------------------------------------------------------------------------------------------
# 👋 Fin de la sesión.

# %% [markdown]
# ## 7. Trazas para entrenamiento GRPO
#
# Las trazas en formato XML estructurado se guardan en `train/grpo_olist_traces.jsonl` listas para **GRPO**. Usa `save_traces=True` en `ask_bi`. Opcional: `send_to_langsmith=True` para enviar a LangSmith.
#
# **LangSmith:** Crea `.env` en la raíz del repo con `LANGCHAIN_API_KEY` y `LANGCHAIN_PROJECT=Olist` (o el nombre de tu proyecto en smith.langchain.com). El módulo carga `.env` automáticamente.

# %%
# save_traces=True guarda en train/grpo_olist_traces.jsonl
# send_to_langsmith=True envía a LangSmith (LANGCHAIN_API_KEY)
# respuesta = ask_bi(db, "¿Mejores vendedores?", provider=PROVIDER, save_traces=True, send_to_langsmith=True)

from duckclaw.bi import load_grpo_traces, trace_stats

stats = trace_stats()
print("Trazas GRPO:", stats)
# load_grpo_traces(limit=5)  # Ver últimas 5 trazas
# Out:
# Trazas GRPO: {'total': 22, 'providers': {'groq': 1, 'mlx': 8, 'deepseek': 13}, 'path': '/Users/juanjosearevalocamargo/Desktop/duckclaw/train/grpo_olist_traces.jsonl'}

# %% [markdown]
# ### Clasificación de recompensas
#
# `classify_traces()` evalúa cada traza (formato, JSON válido, coherencia prompt→tool) y escribe `train/grpo_olist_rewarded.jsonl` con el campo `reward` en [-1.0, 1.0], listo para entrenamiento GRPO.

# %%
from duckclaw.rl import classify_traces, load_rewarded_traces

rewarded, stats = classify_traces()
print("Clasificación:", stats)

# Cargar trazas con reward >= 0.3 para entrenar
train_data = load_rewarded_traces(min_reward=0.3)
print(f"Trazas para entrenar (reward>=0.3): {len(train_data)}")
# Out:
# Clasificación: {'input_path': '/Users/juanjosearevalocamargo/Desktop/duckclaw/train/grpo_olist_traces.jsonl', 'output_path': '/Users/juanjosearevalocamargo/Desktop/duckclaw/train/grpo_olist_rewarded.jsonl', 'total_input': 22, 'total_output': 22, 'filtered': 0, 'min_reward': -0.2, 'max_reward': 1.0, 'avg_reward': 0.43636363636363634}
# Trazas para entrenar (reward>=0.3): 10

# %%
# Ver/exportar log de conversación desde VFS
import pandas as pd

stats = chat_log_stats()
print('📈 Stats:', stats)

log_df = pd.DataFrame(load_chat_log(limit=500))
display(log_df.head(20))

# Limpieza manual opcional
# deleted = prune_chat_log(keep_last=300)
# print(f'🧹 Filas eliminadas: {deleted}')

# Exportar snapshot opcional
# Path('output').mkdir(exist_ok=True)
# log_df.to_csv('output/chat_log_vfs.csv', index=False)
# Out:
# 📈 Stats: {'total_rows': 24, 'providers': [{'provider': 'deepseek', 'n': '13'}, {'provider': 'mlx', 'n': '11'}], 'latest_timestamp': '2026-02-26T16:32:53'}
#               timestamp                                              input  \
# 0   2026-02-26T16:32:53  haz un diagrama de barras con las ventas por m...
# 1   2026-02-26T16:32:28  haz un diagrama de torta con el top 5 de categ...
# 2   2026-02-26T16:31:55                        que tablas hay disponibles?
# 3   2026-02-26T15:07:43     haz un gràfico con las ventas por mes del 2017
# 4   2026-02-26T15:07:16                        que tablas hay disponibles?
# 5   2026-02-26T15:06:59  haz un diagrama de torta con el top 5 de categ...
# 6   2026-02-26T15:03:09  haz un diagrama de torta con las top 5 categor...
# 7   2026-02-26T14:59:41  pasa un diagrama de torta con el top 5 de cate...
# 8   2026-02-26T14:58:52     haz una grafica con las ventas por med de 2017
# 9   2026-02-26T14:58:27                        que tablas hay disponibles?
# 10  2026-02-26T14:51:09          haz una gràfica de ventas por mes en 2018
# 11  2026-02-26T14:50:33                         cual es el mejor vendedor?
# 12  2026-02-26T14:49:56                        que tablas hay disponibles?
# 13  2026-02-24T15:58:03                     cual el cliente con màs ventas
# 14  2026-02-24T15:57:31                   cual es el pais con màs clientes
# 15  2026-02-24T15:56:50               cual es el pais con mayorers ventas?
# 16  2026-02-24T15:44:53                                  que paises estàn?
# 17  2026-02-24T15:44:28                                cuantas tablas hay?
# 18  2026-02-24T15:35:05                                cauntas tablas hay?
# 19  2026-02-24T15:27:04                   cual es el lugar con màs ventas?
#
#                                                output  \
# 0   <answer>\nHe generado el diagrama de barras co...
# 1   <answer>\nHe generado el diagrama de torta con...
# 2   Tablas disponibles: olist_customers, olist_geo...
# 3   <thought>\nLa herramienta se ejecutó correctam...
# 4   Tablas disponibles: olist_customers, olist_geo...
# 5   <thought>\nLa herramienta se ejecutó correctam...
# 6   <thought>\nHe generado un gráfico de barras de...
# 7   <thought>\nHe generado un gráfico de barras co...
# 8   <answer>\nHe generado la gráfica de ventas por...
# 9   <answer>\nEn el dataset Olist hay disponibles ...
# 10  Resumen: 96,478 pedidos, ventas totales 15,419...
# 11  <thought>\n1. Análisis del resultado: Se obtuv...
# 12  Resumen: 96,478 pedidos, ventas totales 15,419...
# 13  Clientes top por ventas: rio de janeiro (13,66...
# 14  Clientes top por ventas: rio de janeiro (13,66...
# 15  Clientes top por ventas: rio de janeiro (13,66...
# 16  Clientes top por ventas: rio de janeiro (13,66...
# 17  Resumen: 96,478 pedidos, ventas totales 15,419...
# 18  No hay datos.\n\nNo hay datos.\n\nNo hay datos...
# 19  Ventas por categoría: health_beauty (1,412,089...
#
#                                            image_path  provider
# 0   /Users/juanjosearevalocamargo/Desktop/duckclaw...  deepseek
# 1   /Users/juanjosearevalocamargo/Desktop/duckclaw...  deepseek
# 2                                                      deepseek
# 3   /Users/juanjosearevalocamargo/Desktop/duckclaw...  deepseek
# 4                                                      deepseek
# 5   /Users/juanjosearevalocamargo/Desktop/duckclaw...  deepseek
# 6   /Users/juanjosearevalocamargo/Desktop/duckclaw...  deepseek
# 7   /Users/juanjosearevalocamargo/Desktop/duckclaw...  deepseek
# 8   /Users/juanjosearevalocamargo/Desktop/duckclaw...  deepseek
# 9                                                      deepseek
# 10                                                     deepseek
# 11                                                     deepseek
# 12                                                     deepseek
# 13                                                          mlx
# 14                                                          mlx
# 15                                                          mlx
# 16                                                          mlx
# 17                                                          mlx
# 18  /Users/juanjosearevalocamargo/Desktop/duckclaw...       mlx
# 19                                                          mlx

# %%
# Mantenimiento rápido del VFS
print('Antes:', chat_log_stats())
deleted = prune_chat_log(keep_last=500)
print(f'🧹 Eliminadas: {deleted}')
print('Después:', chat_log_stats())
# Out:
# Antes: {'total_rows': 24, 'providers': [{'provider': 'deepseek', 'n': '13'}, {'provider': 'mlx', 'n': '11'}], 'latest_timestamp': '2026-02-26T16:32:53'}
# 🧹 Eliminadas: 0
# Después: {'total_rows': 24, 'providers': [{'provider': 'deepseek', 'n': '13'}, {'provider': 'mlx', 'n': '11'}], 'latest_timestamp': '2026-02-26T16:32:53'}

# %% [markdown]
# ## 8. Exportar a DataLake listo para Fabric
#
# **Sincronizar con OneLake:** `pip install -e ".[fabric]"` (azure-storage-file-datalake, azure-identity). Requiere `az login` y FABRIC_WORKSPACE_ID + FABRIC_LAKEHOUSE_ID en .env.

# %%
db.create_datalake(duckclaw.get_datalake_path())
print(f"DataLake exportado a: {duckclaw.get_datalake_path()}")
# Out:
# DataLake exportado a: /Users/juanjosearevalocamargo/Desktop/duckclaw/datalake
